# %%
print("Hello")
# Out:
# Hello

# %%
from pathlib import Path
import requests


def download_one_file_of_raw_data(year: int, month: int) -> Path:
    URL = f"https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{year}-{month:02d}.parquet"
    
    response = requests.get(URL)

    if response.status_code == 200:
        path = f"./data/raw/rides_{year}-{month:02d}.parquet"
        
        open(path, "wb").write(response.content)
        
        return path
    else:
        raise Exception(f"{URL} is not available")

# %%
download_one_file_of_raw_data(2023, 1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 download_one_file_of_raw_data(2023, 1)
#
# Cell In[6], line 13, in download_one_file_of_raw_data(year, month)
#      10 if response.status_code == 200:
#      11     path = f"./data/raw/rides_{year}-{month:02d}.parquet"
# ---> 13     open(path, "wb").write(response.content)
#      15     return path
#      16 else:
#
# File ~\anaconda3\envs\taxi-demand-env\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# ...

# %%
from pathlib import Path

list(Path("../data/raw").glob("*"))
# Out:
# []

# %%
from pathlib import Path

Path("../data/raw").exists()
# Out:
# False

# %%
from pathlib import Path
import requests

def download_one_file_of_raw_data(year: int, month: int):
    url = f"https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{year}-{month:02d}.parquet"

    response = requests.get(url)

    if response.status_code == 200:
        path = Path("../data/raw/rides_{:04d}-{:02d}.parquet".format(year, month))

        path.parent.mkdir(parents=True, exist_ok=True)

        with open(path, "wb") as f:
            f.write(response.content)

        print(f"Saved at: {path}")
    else:
        print("Download failed")

# %%
download_one_file_of_raw_data(2023, 1)
# Out:
# Saved at: ..\data\raw\rides_2023-01.parquet

# %%
from pathlib import Path

list(Path("../data/raw").glob("*"))
# Out:
# [WindowsPath('../data/raw/rides_2023-01.parquet')]

# %%
import pandas as pd

df = pd.read_parquet("../data/raw/rides_2023-01.parquet")
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
import pandas as pd

# %%
# !pip install pandas pyarrow
# !pip install pandas

# %%
import pandas as pd

df = pd.read_parquet("../data/raw/rides_2023-01.parquet")
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\immad\anaconda3\envs\taxi-demand-env\python.exe

# %%
import sys
# !{sys.executable} -m pip install pandas pyarrow

# %%
import pandas as pd

df = pd.read_parquet("../data/raw/rides_2023-01.parquet")
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df = df[["tpep_pickup_datetime","PULocationID"]]

# %%
df.rename(
    columns={
        'tpep_pickup_datetime': 'pickup_datetime',
        'PULocationID': 'user_location_id'
    },
    inplace=True
)

df.head()
# Out:
#       pickup_datetime  user_location_id
# 0 2023-01-01 00:32:10               161
# 1 2023-01-01 00:55:08                43
# 2 2023-01-01 00:25:04                48
# 3 2023-01-01 00:03:48               138
# 4 2023-01-01 00:10:29               107

# %%
df.head()
# Out:
#       pickup_datetime  user_location_id
# 0 2023-01-01 00:32:10               161
# 1 2023-01-01 00:55:08                43
# 2 2023-01-01 00:25:04                48
# 3 2023-01-01 00:03:48               138
# 4 2023-01-01 00:10:29               107

# %%
df = df[
    (df["pickup_datetime"] >= "2023-01-01") &
    (df["pickup_datetime"] < "2023-02-01")
]

# %%
df["pickup_datetime"].min(), df["pickup_datetime"].max()
# Out:
# (Timestamp('2023-01-01 00:00:00'), Timestamp('2023-01-31 23:59:59'))

# %%
df.to_parquet('../data/second/validated_rides_2023_01.parquet')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df.to_parquet('../data/second/validated_rides_2023_01.parquet')
#
# File ~\anaconda3\envs\taxi-demand-env\Lib\site-packages\pandas\core\frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)   3131 >>> content = f.read()
#    3132 """
#    3133 from pandas.io.parquet import to_parquet
# -> 3135 return to_parquet(
#    3136     self,
#    3137     path,
#    3138     engine,
#    3139     compression=compression,
#    3140     index=index,
#    3141     partition_cols=partition_cols,
#    3142     storage_options=storage_options,
#    3143     filesystem=filesystem,
#    3144     **kwargs,
#    3145 )
#
# ...

# %%
df.to_parquet('../data/second/validated_rides_2023_01.parquet')
